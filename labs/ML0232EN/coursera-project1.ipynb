# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/github-repos/repositories.csv

# %% [markdown]
# The object of the notebook is to practice Exploratory Data Analysis(EDA) alongside with a course at Coursera taught by IBM with data set from kaggle.This project is about processing github data about most popular github repositories. Several columns(description,URL, created at, updated at etc have been stripped off to focus on mastering basic skill first and then add them later for advance processing.

# %% [markdown]
# Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = "/kaggle/input/github-repos/repositories.csv"

# %%
dataset = pd.read_csv(path)

# %%
dataset.head()
# Out:
#                           Name  \
# 0                 freeCodeCamp
# 1       free-programming-books
# 2                      awesome
# 3                      996.ICU
# 4  coding-interview-university
#
#                                          Description  \
# 0  freeCodeCamp.org's open-source codebase and cu...
# 1         :books: Freely available programming books
# 2  😎 Awesome lists about all kinds of interesting...
# 3  Repo for counting stars and contributing. Pres...
# 4  A complete computer science study plan to beco...
#
#                                                  URL            Created At  \
# 0       https://github.com/freeCodeCamp/freeCodeCamp  2014-12-24T17:49:19Z
# 1  https://github.com/EbookFoundation/free-progra...  2013-10-11T06:50:37Z
# 2            https://github.com/sindresorhus/awesome  2014-07-11T13:42:37Z
# 3                  https://github.com/996icu/996.ICU  2019-03-26T07:31:14Z
# ...

# %%
dataset.columns
# Out:
# Index(['Name', 'Description', 'URL', 'Created At', 'Updated At', 'Homepage',
#        'Size', 'Stars', 'Forks', 'Issues', 'Watchers', 'Language', 'License',
#        'Topics', 'Has Issues', 'Has Projects', 'Has Downloads', 'Has Wiki',
#        'Has Pages', 'Has Discussions', 'Is Fork', 'Is Archived', 'Is Template',
#        'Default Branch'],
#       dtype='object')

# %%
dataset = dataset.drop(['Name', 'Description', 'URL', 'Created At', 'Updated At', 'Homepage', 'Default Branch', 'Language', 'License', 'Topics'], axis =1)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215029 entries, 0 to 215028
# Data columns (total 14 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Size             215029 non-null  int64
#  1   Stars            215029 non-null  int64
#  2   Forks            215029 non-null  int64
#  3   Issues           215029 non-null  int64
#  4   Watchers         215029 non-null  int64
#  5   Has Issues       215029 non-null  bool
#  6   Has Projects     215029 non-null  bool
#  7   Has Downloads    215029 non-null  bool
#  8   Has Wiki         215029 non-null  bool
#  9   Has Pages        215029 non-null  bool
#  10  Has Discussions  215029 non-null  bool
#  11  Is Fork          215029 non-null  bool
#  12  Is Archived      215029 non-null  bool
#  13  Is Template      215029 non-null  bool
# dtypes: bool(9), int64(5)
# memory usage: 10.0 MB

# %% [markdown]
# Feature transformation.
